# %% [markdown]
# # Atividade 1 — Exercícios com os comandos básicos de pandas para EDA
#
#
# Responda as perguntas abaixo no notebook (cada resposta deve ter ao menos uma célula de código que produza o output e, logo abaixo, uma célula de texto com a sua interpretação).

# %% [markdown]
# ## 1) Carregue o dataset e mostre as primeiras 10 linhas.

# %%
import pandas as pd
url='https://drive.google.com/uc?export=download&id=1eJ-L0MnJxHi929fZrVOKxH7Mrw5eTGpk'
df=pd.read_csv(url)
df.head(10)
# Out:
# /tmp/ipykernel_1385/4026522561.py:3: DtypeWarning: Columns (0,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(url)
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
# 5   Sem informação           2014
# 6   Sem informação           2014
# 7   Sem informação           2014
# 8   Sem informação           2014
# 9   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
# 5  Emenda Individual - Transferências com Finalid...
# ...

# %% [markdown]
# Explique em uma frase o que você observa nas primeiras 10 linhas.
# Dados sobre uma tabela de orçamento e emendas

# %% [markdown]
# ## 2) Quantas linhas e colunas o dataset possui?

# %%
df.shape
# Out:
# (88596, 28)

# %% [markdown]
# Explique o que esses números significam.
# 88596 linhas e 28 colunas

# %% [markdown]
# ## 3) Liste os nomes das colunas e descreva brevemente o que você entende que cada coluna representa.

# %%
df.columns
# Out:
# Index(['Código da Emenda', 'Ano da Emenda', 'Tipo de Emenda',
#        'Código do Autor da Emenda', 'Nome do Autor da Emenda',
#        'Número da emenda', 'Localidade de aplicação do recurso',
#        'Código Município IBGE', 'Município', 'Código UF IBGE', 'UF', 'Região',
#        'Código Função', 'Nome Função', 'Código Subfunção', 'Nome Subfunção',
#        'Código Programa', 'Nome Programa', 'Código Ação', 'Nome Ação',
#        'Código Plano Orçamentário', 'Nome Plano Orçamentário',
#        'Valor Empenhado', 'Valor Liquidado', 'Valor Pago',
#        'Valor Restos A Pagar Inscritos', 'Valor Restos A Pagar Cancelados',
#        'Valor Restos A Pagar Pagos'],
#       dtype='object')

# %% [markdown]
# Escreva sua breve descrição das colunas, como se estivesse criando um dicionário de variáveis para que leitor entenda.

# %% [markdown]
# Código da Emenda: Identificador único da emenda parlamentar no sistema.
#
# Ano da Emenda: Ano em que a emenda foi proposta ou registrada.
#
# Tipo de Emenda: Classificação da emenda (ex: individual, bancada, relator, etc.).
#
# Código do Autor da Emenda: Identificador único do parlamentar autor da emenda.
#
# Nome do Autor da Emenda: Nome do parlamentar responsável pela emenda.
#
# Número da emenda: Número específico da emenda dentro do processo legislativo.
#
# Localidade de aplicação do recurso: Descrição do local onde os recursos da emenda serão aplicados.
#
# Código Município IBGE: Código oficial do município segundo o IBGE.
#
# Município: Nome do município beneficiado pela emenda.
#
# Código UF IBGE: Código da Unidade Federativa (estado) segundo o IBGE.
#
# UF: Sigla do estado onde o recurso será aplicado.
#
# Região: Região geográfica do Brasil (Norte, Nordeste, Centro-Oeste, Sudeste, Sul).
#
# Código Função: Código da função orçamentária (ex: saúde, educação).
#
# Nome Função: Nome da função orçamentária correspondente.
#
# Código Subfunção: Código da subfunção orçamentária (detalhamento da função).
#
# Nome Subfunção: Nome da subfunção orçamentária.
#
# Código Programa: Identificador do programa governamental relacionado à emenda.
#
# Nome Programa: Nome do programa governamental.
#
# Código Ação: Código da ação orçamentária específica.
#
# Nome Ação: Nome da ação orçamentária.
#
# Código Plano Orçamentário: Código do plano orçamentário (detalhamento da ação).
#
# Nome Plano Orçamentário: Nome do plano orçamentário.
#
# Valor Empenhado: Valor reservado no orçamento para pagamento (compromisso assumido).
#
# Valor Liquidado: Valor cuja execução foi confirmada (serviço prestado ou bem entregue).
#
# Valor Pago: Valor efetivamente pago.
#
# Valor Restos A Pagar Inscritos: Valores empenhados, mas não pagos até o final do exercício e inscritos como restos a pagar.
#
# Valor Restos A Pagar Cancelados: Parte dos restos a pagar que foi cancelada.
#
# Valor Restos A Pagar Pagos: Parte dos restos a pagar que foi efetivamente paga posteriormente.

# %% [markdown]
# ## 4) Existem valores nulos? quantos?

# %%
df.isnull().sum()
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             0
# Código UF IBGE                        0
# UF                                    0
# Região                                0
# Código Função                         0
# Nome Função                           0
# Código Subfunção                      0
# Nome Subfunção                        0
# Código Programa                       0
# Nome Programa                         0
# Código Ação                           0
# Nome Ação                             0
# Código Plano Orçamentário             0
# Nome Plano Orçamentário               0
# Valor Empenhado                       0
# ...

# %% [markdown]
# não. 0

# %% [markdown]
# ## 5) Mostre os tipos das variáveis (se int, string, boolean, float...) e analise se alguma variável parece ter o tipo errado. Faça isso da maneira mais objetiva e otimizada possível.

# %%
import pandas as pd
url='https://drive.google.com/uc?export=download&id=1eJ-L0MnJxHi929fZrVOKxH7Mrw5eTGpk'
df=pd.read_csv(url)
df.info()
# Out:
# /tmp/ipykernel_4585/3377203551.py:3: DtypeWarning: Columns (0,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(url)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88596 entries, 0 to 88595
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Código da Emenda                    88596 non-null  object
#  1   Ano da Emenda                       88596 non-null  int64
#  2   Tipo de Emenda                      88596 non-null  object
#  3   Código do Autor da Emenda           88596 non-null  object
#  4   Nome do Autor da Emenda             88596 non-null  object
#  5   Número da emenda                    88596 non-null  object
#  6   Localidade de aplicação do recurso  88596 non-null  object
#  7   Código Município IBGE               88596 non-null  object
# ...

# %% [markdown]
# Se alguma coluna estiver com o tipo errado, escreva abaixo qual é e por que isso pode atrapalhar análises.
#
# **Dica:** Se alguma variável tiver no tipo o nome "object", isso se refere a texto.

# %% [markdown]
# colunas 22 a 27 deveriam ser numéricos, float.
# coluna 5 poderia ser  int

# %% [markdown]
# ## 6) Usando a coluna `Ano da Emenda` como base, descubra até que ano o dataset está atualizado (mostre as 8 primeiras linhas do df ordenado desc).

# %%
print(df.sort_values(by="Ano da Emenda", ascending=False).head(8))
print("Dataset atualizado até:", df["Ano da Emenda"].max())
# Out:
#       Código da Emenda  Ano da Emenda  \
# 88564     202541820003           2025
# 88578     202544940001           2025
# 88595     202544840009           2025
# 88594     202544840008           2025
# 88577     202541820017           2025
# 88576     202541820016           2025
# 88575     202541820015           2025
# 88574     202541820014           2025
#
#                                           Tipo de Emenda  \
# 88564       Emenda Individual - Transferências Especiais
# 88578  Emenda Individual - Transferências com Finalid...
# 88595  Emenda Individual - Transferências com Finalid...
# 88594  Emenda Individual - Transferências com Finalid...
# 88577  Emenda Individual - Transferências com Finalid...
# 88576  Emenda Individual - Transferências com Finalid...
# 88575  Emenda Individual - Transferências com Finalid...
# 88574  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# ...

# %% [markdown]
# Explique: qual é o ano mais recente presente no dataset?O ano mais recente presente no dataset é 2025

# %% [markdown]
# ## 7) execute um  `describe()` e explique uma conclusão simples que você consegue tirar a partir das estatísticas (se algumas colunas deveriam aparecer no describe mas não aparecem, indique o motivo que você acredita que esteja causando esse problema).

# %%
df.describe()
# Out:
#        Ano da Emenda  Código UF IBGE
# count   88596.000000    8.859600e+04
# mean     2019.155109    2.943594e+06
# std         3.409323    1.264884e+06
# min      2014.000000   -1.400000e+01
# 25%      2016.000000    2.300000e+06
# 50%      2019.000000    3.100000e+06
# 75%      2022.000000    3.500000e+06
# max      2025.000000    5.300000e+06

# %% [markdown]
# a maioria das emendas está concentrada entre 2016 e 2022, indicando que os dados são relativamente recentes. Algumas colunas não aparecem na análise porque estão no formato de texto, como valores monetários com vírgula, o que impede sua interpretação como dados numéricos.

# %% [markdown]
# ## 8) Mostre as últimas 5 linhas do dataset e escreva se a última linha parece completa (sem muitos nulos) ou não.

# %%
df.tail(5)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 88591     202544840005           2025
# 88592     202544840006           2025
# 88593     202544840007           2025
# 88594     202544840008           2025
# 88595     202544840009           2025
#
#                                           Tipo de Emenda  \
# 88591       Emenda Individual - Transferências Especiais
# 88592  Emenda Individual - Transferências com Finalid...
# 88593  Emenda Individual - Transferências com Finalid...
# 88594  Emenda Individual - Transferências com Finalid...
# 88595  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 88591                      4484                   ZUCCO                5
# 88592                      4484                   ZUCCO                6
# 88593                      4484                   ZUCCO                7
# 88594                      4484                   ZUCCO                8
# ...

# %% [markdown]
# Interprete a completude da última linha. Não há valores nulos, apenas campos com “Sem informação” e valores zero, que são válidos.

# %% [markdown]
# ## 9) existem valores duplicados no dataframe? Caso positivo, quantos?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Não existem valores duplicados no dataframe,
